# %% [markdown]
# <a href="https://colab.research.google.com/github/DewliniHerath/Telco_Churn_Predictor/blob/main/notebooks/Telco_dataPreprocess_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data Preprocessing for Neural Network**
